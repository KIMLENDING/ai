# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2-cp39-cp39-win_amd64.whl (153 kB)
#      -------------------------------------- 153.1/153.1 kB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.6.1 in c:\users\gotsl\anaconda3\lib\site-packages (from wordcloud) (1.22.4)
# Requirement already satisfied: matplotlib in c:\users\gotsl\anaconda3\lib\site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: pillow in c:\users\gotsl\anaconda3\lib\site-packages (from wordcloud) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\gotsl\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\gotsl\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\gotsl\anaconda3\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\gotsl\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gotsl\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gotsl\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\gotsl\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.2.2

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Womens Clothing E-Commerce Reviews(수정).csv 데이터를 pandas를 사용하여 dataframe 형태로 불러옵니다.
df_origin = pd.read_csv("C:/Users/gotsl/Desktop/Womens Clothing E-Commerce Reviews(수정).csv")

# %%
# 5개의 데이터 샘플을 출력합니다.
df_origin.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  Clothing ID  Age                    Title  \
# 0             0           0          767   33                      NaN
# 1             1           1         1080   34                      NaN
# 2             2           2         1077   60  Some major design flaws
# 3             3           3         1049   50         My favorite buy!
# 4             4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                0
# 1  Love this dress!  it's sooo pretty.  i happene...       5                0
# 2  I had such high hopes for this dress and reall...       3                1
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                0
# 4  This shirt is very flattering to all due to th...       5                0
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses

# %%
# dataframe의 정보를 요약해서 출력합니다.
df_origin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23486 entries, 0 to 23485
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0.1             23486 non-null  int64
#  1   Unnamed: 0               23486 non-null  int64
#  2   Clothing ID              23486 non-null  int64
#  3   Age                      23486 non-null  int64
#  4   Title                    19676 non-null  object
#  5   Review Text              22641 non-null  object
#  6   Rating                   23486 non-null  int64
#  7   Recommended IND          23486 non-null  int64
#  8   Positive Feedback Count  23486 non-null  int64
#  9   Division Name            23472 non-null  object
#  10  Department Name          23472 non-null  object
#  11  Class Name               23472 non-null  object
# dtypes: int64(7), object(5)
# memory usage: 2.2+ MB

# %%
# 수치형 변수의 데이터 정보를 요약하여 출력합니다.
df_origin.describe()
# Out:
#        Unnamed: 0.1    Unnamed: 0   Clothing ID           Age        Rating  \
# count  23486.000000  23486.000000  23486.000000  23486.000000  23486.000000
# mean   11742.500000  11742.500000    918.118709     43.198544      4.196032
# std     6779.968547   6779.968547    203.298980     12.279544      1.110031
# min        0.000000      0.000000      0.000000     18.000000      1.000000
# 25%     5871.250000   5871.250000    861.000000     34.000000      4.000000
# 50%    11742.500000  11742.500000    936.000000     41.000000      5.000000
# 75%    17613.750000  17613.750000   1078.000000     52.000000      5.000000
# max    23485.000000  23485.000000   1205.000000     99.000000      5.000000
#
#        Recommended IND  Positive Feedback Count
# count     23486.000000             23486.000000
# mean          0.177638                 2.535936
# std           0.382216                 5.702202
# min           0.000000                 0.000000
# 25%           0.000000                 0.000000
# 50%           0.000000                 1.000000
# 75%           0.000000                 3.000000
# max           1.000000               122.000000

# %%
2. 데이터 정제
일반적으로 데이터 정제에서는 결측값(missing value) 또는 이상치(outlier)를 처리합니다.

이상치 데이터는 각 변수의 특성에 맞게 처리하는 것이 좋기에 각 변수를 살펴보는 데이터 시각화를 수행하며 필요하게 된다면 추가 적으로 수행하겠습니다.

따라서 이번 파트에서는 간단하게 결측값에 대해서만 처리를 수행하겠습니다.
# Out:
#   Input In [9]
#     2. 데이터 정제
#        ^
# SyntaxError: invalid syntax

# %%
# 결측값을 처리하기 전에 우선 의미 없는 변수인 'Unnamed: 0, Unnamed: 0.1'를 drop을 사용하여 삭제합니다.
df_clean = df_origin.drop(columns = ['Unnamed: 0', 'Unnamed: 0.1'])

# %%
df_clean
# Out:
#        Clothing ID  Age                                              Title  \
# 0              767   33                                                NaN
# 1             1080   34                                                NaN
# 2             1077   60                            Some major design flaws
# 3             1049   50                                   My favorite buy!
# 4              847   47                                   Flattering shirt
# ...            ...  ...                                                ...
# 23481         1104   34                     Great dress for many occasions
# 23482          862   48                         Wish it was made of cotton
# 23483         1104   31                              Cute, but see through
# 23484         1084   28  Very cute dress, perfect for summer parties an...
# 23485         1104   52                    Please make more like this one!
#
#                                              Review Text  Rating  \
# 0      Absolutely wonderful - silky and sexy and comf...       4
# 1      Love this dress!  it's sooo pretty.  i happene...       5
# 2      I had such high hopes for this dress and reall...       3
# 3      I love, love, love this jumpsuit. it's fun, fl...       5
# 4      This shirt is very flattering to all due to th...       5
# ...                                                  ...     ...
# 23481  I was very happy to snag this dress at such a ...       5
# 23482  It reminds me of maternity clothes. soft, stre...       3
# 23483  This fit well, but the top was very see throug...       3
# 23484  I bought this dress for a wedding i have this ...       3
# 23485  This dress in a lovely platinum is feminine an...       5
#
#        Recommended IND  Positive Feedback Count   Division Name  \
# 0                    0                        0       Initmates
# 1                    0                        4         General
# 2                    1                        0         General
# 3                    0                        0  General Petite
# 4                    0                        6         General
# ...                ...                      ...             ...
# 23481                0                        0  General Petite
# 23482                0                        0  General Petite
# 23483                1                        1  General Petite
# 23484                0                        2         General
# 23485                0                       22  General Petite
#
#       Department Name Class Name
# 0            Intimate  Intimates
# 1             Dresses    Dresses
# 2             Dresses    Dresses
# 3             Bottoms      Pants
# 4                Tops    Blouses
# ...               ...        ...
# 23481         Dresses    Dresses
# 23482            Tops      Knits
# 23483         Dresses    Dresses
# 23484         Dresses    Dresses
# 23485         Dresses    Dresses
#
# [22641 rows x 10 columns]

# %%
# 결측값 정보를 출력합니다.
df_clean.isnull().sum()
# Out:
# Clothing ID                   0
# Age                           0
# Title                      3810
# Review Text                 845
# Rating                        0
# Recommended IND               0
# Positive Feedback Count       0
# Division Name                14
# Department Name              14
# Class Name                   14
# dtype: int64

# %%
# 아래 3개의 변수들의 결측값 정보를 알아보고 싶어서 그 데이터들을 출력합니다.
df_clean[df_clean['Division Name'].isnull()]
# Out:
#        Clothing ID  Age                                  Title  \
# 9444            72   25                   My favorite socks!!!
# 13767          492   23                               So soft!
# 13768          492   49                        Wardrobe staple
# 13787          492   48                                    NaN
# 16216          152   36                          Warm and cozy
# 16221          152   37                                  Love!
# 16223          152   39                        "long and warm"
# 18626          184   34                  Nubby footless tights
# 18671          184   54                          New workhorse
# 20088          772   50                      Comfy sweatshirt!
# 21532          665   43                           So worth it!
# 22997          136   47  Charcoal, pale gray, a bit of silver!
# 23006          136   33                        Cute itsy socks
# 23011          136   36                            Super socks
#
#                                              Review Text  Rating  \
# 9444   I never write reviews, but these socks are so ...       5
# 13767  I just love this hoodie! it is so soft and com...       5
# 13768  Love this hoodie. so soft and goes with everyt...       5
# 13787                                                NaN       5
# 16216  Just what i was looking for. soft, cozy and warm.       5
# 16221  I am loving these. they are quite long but are...       5
# 16223  These leg warmers are perfect for me. they are...       5
# 18626  These are amazing quality. i agree, size up to...       5
# 18671  These tights are amazing! if i care for them w...       5
# 20088  This sweatshirt is really nice!  it's oversize...       5
# 21532  Got these on sale...absolutely love eberjey! f...       5
# 22997  These socks are soft and comfortable, and they...       5
# 23006  Love polkadots, love sparkle. these little soc...       5
# 23011  I love these little socks ? and the dots spark...       5
#
#        Recommended IND  Positive Feedback Count Division Name Department Name  \
# 9444                 0                        0           NaN             NaN
# 13767                0                        1           NaN             NaN
# 13768                0                        0           NaN             NaN
# 13787                0                        0           NaN             NaN
# 16216                0                        0           NaN             NaN
# 16221                0                        0           NaN             NaN
# 16223                0                        0           NaN             NaN
# 18626                0                        5           NaN             NaN
# 18671                0                        0           NaN             NaN
# 20088                0                        0           NaN             NaN
# 21532                0                        0           NaN             NaN
# 22997                0                        1           NaN             NaN
# 23006                0                        0           NaN             NaN
# 23011                0                        0           NaN             NaN
#
#       Class Name
# 9444         NaN
# 13767        NaN
# 13768        NaN
# 13787        NaN
# 16216        NaN
# 16221        NaN
# 16223        NaN
# 18626        NaN
# 18671        NaN
# 20088        NaN
# 21532        NaN
# 22997        NaN
# 23006        NaN
# 23011        NaN

# %%
# 결측값이 아닌 부분을 골라내어 df_clasn에 저장합니다.
df_clean = df_clean[~df_clean['Review Text'].isnull()]

# %%
# 결측값 정보를 출력합니다.
df_clean.isnull().sum()
# Out:
# Clothing ID                   0
# Age                           0
# Title                      2966
# Review Text                   0
# Rating                        0
# Recommended IND               0
# Positive Feedback Count       0
# Division Name                13
# Department Name              13
# Class Name                   13
# dtype: int64

# %%
import nltk
from nltk.corpus import stopwords
from nltk import sent_tokenize, word_tokenize
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from collections import Counter
from nltk.tokenize import RegexpTokenizer
import re

# %%
# 'Title'의 결측값을 삭제합니다.
df_clean_title = df_clean[~df_clean['Title'].isnull()]

# findall 함수를 사용하여 띄어 쓰기 단위로 글자만을 가져옵니다.(소문자로 변환도 수행)
tokens = re.findall("[\w']+", df_clean_title['Title'].str.lower().str.cat(sep=' '))

# %%
tokens
# Out:
# ['some',
#  'major',
#  'design',
#  'flaws',
#  'my',
#  'favorite',
#  'buy',
#  'flattering',
#  'shirt',
#  'not',
#  'for',
#  'the',
#  'very',
#  'petite',
#  'cagrcoal',
#  'shimmer',
#  'fun',
#  'shimmer',
#  'surprisingly',
#  'goes',
#  'with',
#  'lots',
#  'flattering',
#  'such',
#  'a',
#  'fun',
#  'dress',
#  'dress',
#  'looks',
#  'like',
#  "it's",
#  'made',
#  'of',
#  'cheap',
#  'material',
#  'perfect',
#  'runs',
#  'big',
#  'pretty',
#  'party',
#  'dress',
#  'with',
#  'some',
#  'issues',
#  'nice',
#  'but',
#  'not',
#  'for',
#  'my',
#  'body',
#  'you',
#  'need',
#  'to',
#  'be',
#  'at',
#  'least',
#  'average',
#  'height',
#  'or',
#  'taller',
#  'looks',
#  'great',
#  'with',
#  'white',
#  'pants',
#  'super',
#  'cute',
#  'and',
#  'cozy',
#  'stylish',
#  'and',
#  'comfortable',
#  'cute',
#  'crisp',
#  'shirt',
#  "i'm",
#  'torn',
#  'not',
#  'what',
#  'it',
#  'looks',
#  'like',
#  'like',
#  'it',
#  'but',
#  "don't",
#  'love',
#  'it',
#  'versatile',
#  'falls',
#  'flat',
#  'huge',
#  'disappointment',
#  'loved',
#  'but',
#  'returned',
#  'great',
#  'shirt',
#  'great',
#  'layering',
#  'piece',
#  'cuter',
#  'in',
#  'oerson',
#  'love',
#  'these',
#  'pants',
#  'mehh',
#  'love',
#  'this',
#  'dress',
#  'lovely',
#  'beautifully',
#  'cut',
#  'lightweight',
#  'coat',
#  'soft',
#  'lovely',
#  'some',
#  'things',
#  'you',
#  'should',
#  'know',
#  'beautiful',
#  'love',
#  'the',
#  'two',
#  'tone',
#  'design',
#  'love',
#  'the',
#  'color',
#  'love',
#  'the',
#  'embroidery',
#  'cute',
#  'for',
#  'fall',
#  'love',
#  'flattering',
#  'and',
#  'comfortable',
#  'cute',
#  'top',
#  'soft',
#  'and',
#  'cute',
#  'as',
#  'can',
#  'be',
#  'boring',
#  'front',
#  'great',
#  'back',
#  'soft',
#  'and',
#  'comfortable',
#  'gorgeous',
#  'dress',
#  'itchy',
#  'tags',
#  'must',
#  'have',
#  'cute',
#  'top',
#  'love',
#  'the',
#  'brand',
#  'love',
#  'this',
#  'top',
#  'super',
#  'cute',
#  'and',
#  'unique',
#  'top',
#  'beautiful',
#  'top',
#  'i',
#  'wanted',
#  'to',
#  'love',
#  'this',
#  'top',
#  'great',
#  'summer',
#  'fabric',
#  'cute',
#  'but',
#  'massive',
#  'sweep',
#  'short',
#  'and',
#  'boxy',
#  'beautiful',
#  'design',
#  'very',
#  'very',
#  'cute',
#  'but',
#  'a',
#  'lot',
#  'of',
#  'fabric',
#  'runs',
#  'large',
#  'in',
#  'top',
#  'and',
#  'waist',
#  'zipper',
#  'broke',
#  'obsessed',
#  'so',
#  'cute',
#  'but',
#  'dry',
#  'clean',
#  'elegant',
#  'classic',
#  'dress',
#  'cute',
#  'parka',
#  'just',
#  'lovely',
#  'casual',
#  'unique',
#  'tee',
#  'neutral',
#  'blue',
#  'true',
#  'to',
#  'size',
#  'to',
#  'large',
#  'huge',
#  'pretty',
#  'but',
#  'not',
#  'for',
#  'me',
#  'sweet',
#  'flattering',
#  'dress',
#  'beautifully',
#  'made',
#  'but',
#  'not',
#  'versatile',
#  'casual',
#  'elegance',
#  'huge',
#  'pernette',
#  'henley',
#  'comfy',
#  'simple',
#  'stylish',
#  'lovely',
#  'runs',
#  'a',
#  'bit',
#  'big',
#  'stunning',
#  'lace',
#  'top',
#  'not',
#  'a',
#  'fan',
#  'excited',
#  'but',
#  'beautiful',
#  'shirt',
#  'but',
#  'runs',
#  'small',
#  'beautiful',
#  'perfect',
#  'fall',
#  'shirt',
#  'poor',
#  'quality',
#  'an',
#  'almost',
#  'for',
#  'me',
#  'beautiful',
#  'stunning',
#  'cozy',
#  'top',
#  'cute',
#  'and',
#  'comfy',
#  'disappointing',
#  'quality',
#  'cute',
#  'tee',
#  'very',
#  'vintage',
#  'feel',
#  'awkward',
#  'fitting',
#  'cozy',
#  'casual',
#  'perfect',
#  'for',
#  'fall',
#  'the',
#  'perfect',
#  'striped',
#  't',
#  'so',
#  'beautiful',
#  'gorgeous',
#  'orange',
#  'color',
#  'lovely',
#  'top',
#  'not',
#  'lovely',
#  'shape',
#  'wonderfully',
#  'made',
#  'poorly',
#  'designed',
#  'for',
#  'busty',
#  'gals',
#  'cute',
#  'vest',
#  'but',
#  'great',
#  'top',
#  'just',
#  'ok',
#  'pernette',
#  'henley',
#  'stylish',
#  'and',
#  'versatile',
#  "you'll",
#  'smile',
#  'on',
#  'a',
#  'humid',
#  "summer's",
#  'day',
#  'a',
#  'new',
#  'staple',
#  'for',
#  'my',
#  'wardrobe',
#  'runs',
#  'short',
#  'feminine',
#  'alternative',
#  'to',
#  'your',
#  'shapeless',
#  'puffer',
#  'love',
#  'love',
#  'love',
#  'this',
#  'skirt',
#  'pretry',
#  'top',
#  'great',
#  'classic',
#  'beautiful',
#  'but',
#  'scratchy',
#  'on',
#  'the',
#  'fence',
#  'so',
#  'pretty',
#  'a',
#  'bit',
#  'long',
#  'and',
#  'bigger',
#  'than',
#  'what',
#  'i',
#  'read',
#  'cute',
#  'skirt',
#  'very',
#  'pretty',
#  'a',
#  'beautiful',
#  'skirt',
#  'gorgeous',
#  'skirt',
#  'beautiful',
#  'not',
#  'impressed',
#  'fair',
#  'great',
#  'colors',
#  'but',
#  'beautiful',
#  'colors',
#  'australian',
#  'sizing',
#  'vibrant',
#  'metallic',
#  'so',
#  'sad',
#  'not',
#  'mine',
#  'scratchy',
#  'uncomfortable',
#  'top',
#  'yes',
#  "it's",
#  'scratchy',
#  'but',
#  'it',
#  'can',
#  'work',
#  'out',
#  'classy',
#  'and',
#  'cute',
#  'so',
#  'pretty',
#  'just',
#  'as',
#  'pictured',
#  'great',
#  'purchase',
#  'antoher',
#  'beautiful',
#  'maeve',
#  'dress',
#  'fun',
#  'comfy',
#  'and',
#  'adorable',
#  'beautiful',
#  'fabric',
#  'and',
#  'style',
#  'great',
#  'for',
#  'summer',
#  'wonderful',
#  'but',
#  'going',
#  'back',
#  'comfy',
#  'casual',
#  'shirt',
#  'perfect',
#  'casual',
#  'sweater',
#  'not',
#  'for',
#  'me',
#  'perfect',
#  'for',
#  'warmer',
#  'climates',
#  'need',
#  'petite',
#  'fun',
#  'completes',
#  'so',
#  'many',
#  'outfits',
#  'size',
#  'up',
#  'not',
#  'as',
#  'pictured',
#  'fits',
#  'strange',
#  'flimsy',
#  'material',
#  'nice',
#  'color',
#  'love',
#  'the',
#  'snap',
#  'buttons',
#  'modern',
#  'comfort',
#  "it's",
#  'gorgeous',
#  'but',
#  'runs',
#  'very',
#  'small',
#  'pretty',
#  'nice',
#  'but',
#  'too',
#  'thin',
#  'lovely',
#  'and',
#  'feminine',
#  'a',
#  'great',
#  'piece',
#  'love',
#  'everything',
#  'about',
#  'this',
#  'skirt',
#  'perfect',
#  'comfy',
#  'now',
#  'top',
#  'poor',
#  'quality',
#  'huuuuge',
#  'not',
#  'worth',
#  'cost',
#  'tunic',
#  "doesn't",
#  'look',
#  'like',
#  'i',
#  'am',
#  'covering',
#  'up',
#  'too',
#  'big',
#  'runs',
#  'small',
#  'too',
#  'bad',
#  'skirt',
#  'dimensions',
#  'are',
#  'off',
#  'comfort',
#  'style',
#  'classic',
#  'my',
#  'new',
#  'favorite',
#  'dress',
#  'not',
#  'as',
#  'pictured',
#  'autumn',
#  'fever',
#  'very',
#  'small',
#  'too',
#  'cute',
#  'to',
#  'pass',
#  'up',
#  'falling',
#  'goddess',
#  'pretty',
#  'and',
#  'comfy',
#  'perfect',
#  'skirt',
#  'easy',
#  'comfy',
#  'cute',
#  'gorgeous',
#  'pretty',
#  'great',
#  'crop',
#  'pant',
#  'cute',
#  'why',
#  'so',
#  'long',
#  'runs',
#  'large',
#  'bohemian',
#  'wonderful',
#  'weight',
#  'for',
#  'summer',
#  'flattering',
#  'light',
#  'large',
#  'must',
#  'have',
#  'right',
#  'on',
#  'trend',
#  'but',
#  'still',
#  'classic',
#  'pretty',
#  'but',
#  'runs',
#  'large',
#  'comfortable',
#  'stylish',
#  'crop',
#  'pants',
#  'cozy',
#  'sunday',
#  'not',
#  'what',
#  'i',
#  'expected',
#  'fun',
#  'change',
#  'from',
#  'the',
#  'norm',
#  'perfect',
#  'for',
#  'mediterenian',
#  'summer',
#  'loved',
#  'this',
#  'then',
#  'washed',
#  'it',
#  'twice',
#  'and',
#  'it',
#  'fell',
#  'apart',
#  'super',
#  'flattering',
#  'recommend',
#  'but',
#  'not',
#  'for',
#  'me',
#  'love',
#  'this',
#  'cute',
#  'but',
#  'small',
#  'really',
#  'nice',
#  'sweater',
#  'coat',
#  'perfect',
#  'very',
#  'cute',
#  'top',
#  'super',
#  'cute',
#  'pants',
#  'cute',
#  'casual',
#  'dress',
#  'runs',
#  'big',
#  'stylish',
#  'and',
#  'understated',
#  'elegant',
#  'pockets',
#  'fits',
#  'like',
#  'a',
#  'maternity',
#  'top',
#  'love',
#  'this',
#  'top',
#  'love',
#  'this',
#  'coat',
#  'adorable',
#  'and',
#  'flattering',
#  'cute',
#  'but',
#  'no',
#  'go',
#  'pretty',
#  'denim',
#  'jacket',
#  'amazing',
#  'peach',
#  'color',
#  'perfection',
#  'nice',
#  'quality',
#  'but',
#  'too',
#  'short',
#  'for',
#  'my',
#  'tall',
#  'frame',
#  'cute',
#  'top',
#  'but',
#  'back',
#  'is',
#  'more',
#  'of',
#  'a',
#  'jersey',
#  'material',
#  'nice',
#  'color',
#  'perfect',
#  'jean',
#  'jacket',
#  'great',
#  'asset',
#  'gorgeous',
#  'comfy',
#  'and',
#  'fun',
#  'great',
#  'tee',
#  'pretty',
#  'and',
#  'feminine',
#  'sooooooooo',
#  'cute',
#  'peplum',
#  'hem',
#  'tee',
#  'so',
#  'comfortable',
#  'and',
#  'chic',
#  'perfect',
#  'sweatshirt',
#  'clever',
#  'white',
#  'edges',
#  'love',
#  'this',
#  'dress',
#  'not',
#  'much',
#  'structure',
#  'boxy',
#  'almost',
#  'perfect',
#  'denim',
#  'jacket',
#  'perfect',
#  'super',
#  'nice',
#  'i',
#  'wish',
#  'it',
#  'were',
#  'alless',
#  'stiff',
#  'denim',
#  'runs',
#  'small',
#  'terrific',
#  'denim',
#  'jacket',
#  'cute',
#  'versatile',
#  'culottes',
#  'my',
#  'new',
#  'favorite',
#  'denim',
#  'jacket',
#  'favorite',
#  'jean',
#  'jacket',
#  'perfect',
#  'denim',
#  'jacket',
#  'best',
#  'dress',
#  'ever',
#  'stylish',
#  'jacket',
#  'adorable',
#  'stunning',
#  'flattering',
#  'and',
#  'versatile',
#  'pretty',
#  'blouse',
#  'too',
#  'distressed',
#  'stunning',
#  'cute',
#  'top',
#  'runs',
#  'large',
#  'and',
#  'zipper',
#  'sticks',
#  'very',
#  'unflattering',
#  'adorable',
#  "didn't",
#  'work',
#  'for',
#  'me',
#  'beautiful',
#  'top',
#  'love',
#  'this',
#  'blouse',
#  'lovely',
#  'printed',
#  'blouse',
#  'love',
#  'love',
#  'love',
#  'loveee',
#  'my',
#  'favorite',
#  'new',
#  'blouse',
#  'a',
#  'standout',
#  'lovely',
#  'disappointing',
#  'better',
#  'in',
#  'person',
#  'cuter',
#  'is',
#  'person',
#  'airy',
#  'and',
#  'flattering',
#  'awkward',
#  'fit',
#  'beautiful',
#  'color',
#  'really',
#  'good',
#  'quality',
#  'tee',
#  'cute',
#  'top',
#  'not',
#  'a',
#  'good',
#  'fit',
#  'cutest',
#  'vest',
#  'beautiful',
#  'vintage',
#  'feel',
#  'delicate',
#  'beadwork',
#  'very',
#  'interesting',
#  'design',
#  'fun',
#  'and',
#  'flowy',
#  'beautiful',
#  'shirt',
#  'beautiful',
#  'fabric',
#  'nice',
#  'basic',
#  'piece',
#  'will',
#  'get',
#  'a',
#  'lot',
#  'of',
#  'wear',
#  'soft',
#  'patterned',
#  'long',
#  'vest',
#  'great',
#  'piece',
#  'beautiful',
#  'and',
#  'timeless',
#  'cute',
#  'top',
#  'but',
#  'not',
#  'for',
#  'me',
#  'so',
#  'disappointed',
#  'please',
#  'fix',
#  'it',
#  'ruffled',
#  'buttondown',
#  'exquisite',
#  'blouse',
#  'runs',
#  'huge',
#  'sweater',
#  'not',
#  'a',
#  'coat',
#  'soft',
#  'sweater',
#  'could',
#  'have',
#  'been',
#  'cute',
#  'worth',
#  'the',
#  'sale',
#  'price',
#  'almost',
#  'but',
#  'not',
#  'quite',
#  'nice',
#  'runs',
#  'small',
#  'and',
#  'short',
#  'amazing',
#  'sweatercoat',
#  'great',
#  'piece',
#  'for',
#  'layering',
#  'cute',
#  'but',
#  'nice',
#  'thin',
#  'sweatshirt',
#  'that',
#  'special',
#  'lauer',
#  'comfy',
#  'and',
#  'cute',
#  'looks',
#  'better',
#  'when',
#  'tried',
#  'on',
#  'very',
#  'cute',
#  'romantic',
#  'print',
#  'elegant',
#  'beautiful',
#  'i',
#  'love',
#  'it',
#  'positively',
#  'agree',
#  'love',
#  'the',
#  'print',
#  'style',
#  'so',
#  'cool',
#  'modern',
#  'black',
#  'and',
#  'white',
#  'subdued',
#  'sexy',
#  'so',
#  'sexy',
#  'just',
#  'okay',
#  'one',
#  'of',
#  'my',
#  'favorite',
#  'pieces',
#  'for',
#  'night',
#  'elegant',
#  'and',
#  'eye',
#  'catching',
#  'work',
#  'appropriate',
#  'lace',
#  'poor',
#  'quality',
#  'soft',
#  'and',
#  'cozy',
#  'looks',
#  'are',
#  'deceiving',
#  'terrific',
#  'sweater',
#  'with',
#  'great',
#  'detail',
#  'runs',
#  'large',
#  ...]

# %%
# nltk에서 지원하는 'stopwords'를 다운받습니다.
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\gotsl\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# 영어 'stopwords'를 가져옵니다.
en_stops = set(stopwords.words('english'))

# tokens에서 'stopwords'에 해당되지 않는 단어를 골라내어 filtered_sentence에 저장합니다.
filtered_sentence = [token for token in tokens if not token in en_stops]
filtered_sentence
# Out:
# ['major',
#  'design',
#  'flaws',
#  'favorite',
#  'buy',
#  'flattering',
#  'shirt',
#  'petite',
#  'cagrcoal',
#  'shimmer',
#  'fun',
#  'shimmer',
#  'surprisingly',
#  'goes',
#  'lots',
#  'flattering',
#  'fun',
#  'dress',
#  'dress',
#  'looks',
#  'like',
#  'made',
#  'cheap',
#  'material',
#  'perfect',
#  'runs',
#  'big',
#  'pretty',
#  'party',
#  'dress',
#  'issues',
#  'nice',
#  'body',
#  'need',
#  'least',
#  'average',
#  'height',
#  'taller',
#  'looks',
#  'great',
#  'white',
#  'pants',
#  'super',
#  'cute',
#  'cozy',
#  'stylish',
#  'comfortable',
#  'cute',
#  'crisp',
#  'shirt',
#  "i'm",
#  'torn',
#  'looks',
#  'like',
#  'like',
#  'love',
#  'versatile',
#  'falls',
#  'flat',
#  'huge',
#  'disappointment',
#  'loved',
#  'returned',
#  'great',
#  'shirt',
#  'great',
#  'layering',
#  'piece',
#  'cuter',
#  'oerson',
#  'love',
#  'pants',
#  'mehh',
#  'love',
#  'dress',
#  'lovely',
#  'beautifully',
#  'cut',
#  'lightweight',
#  'coat',
#  'soft',
#  'lovely',
#  'things',
#  'know',
#  'beautiful',
#  'love',
#  'two',
#  'tone',
#  'design',
#  'love',
#  'color',
#  'love',
#  'embroidery',
#  'cute',
#  'fall',
#  'love',
#  'flattering',
#  'comfortable',
#  'cute',
#  'top',
#  'soft',
#  'cute',
#  'boring',
#  'front',
#  'great',
#  'back',
#  'soft',
#  'comfortable',
#  'gorgeous',
#  'dress',
#  'itchy',
#  'tags',
#  'must',
#  'cute',
#  'top',
#  'love',
#  'brand',
#  'love',
#  'top',
#  'super',
#  'cute',
#  'unique',
#  'top',
#  'beautiful',
#  'top',
#  'wanted',
#  'love',
#  'top',
#  'great',
#  'summer',
#  'fabric',
#  'cute',
#  'massive',
#  'sweep',
#  'short',
#  'boxy',
#  'beautiful',
#  'design',
#  'cute',
#  'lot',
#  'fabric',
#  'runs',
#  'large',
#  'top',
#  'waist',
#  'zipper',
#  'broke',
#  'obsessed',
#  'cute',
#  'dry',
#  'clean',
#  'elegant',
#  'classic',
#  'dress',
#  'cute',
#  'parka',
#  'lovely',
#  'casual',
#  'unique',
#  'tee',
#  'neutral',
#  'blue',
#  'true',
#  'size',
#  'large',
#  'huge',
#  'pretty',
#  'sweet',
#  'flattering',
#  'dress',
#  'beautifully',
#  'made',
#  'versatile',
#  'casual',
#  'elegance',
#  'huge',
#  'pernette',
#  'henley',
#  'comfy',
#  'simple',
#  'stylish',
#  'lovely',
#  'runs',
#  'bit',
#  'big',
#  'stunning',
#  'lace',
#  'top',
#  'fan',
#  'excited',
#  'beautiful',
#  'shirt',
#  'runs',
#  'small',
#  'beautiful',
#  'perfect',
#  'fall',
#  'shirt',
#  'poor',
#  'quality',
#  'almost',
#  'beautiful',
#  'stunning',
#  'cozy',
#  'top',
#  'cute',
#  'comfy',
#  'disappointing',
#  'quality',
#  'cute',
#  'tee',
#  'vintage',
#  'feel',
#  'awkward',
#  'fitting',
#  'cozy',
#  'casual',
#  'perfect',
#  'fall',
#  'perfect',
#  'striped',
#  'beautiful',
#  'gorgeous',
#  'orange',
#  'color',
#  'lovely',
#  'top',
#  'lovely',
#  'shape',
#  'wonderfully',
#  'made',
#  'poorly',
#  'designed',
#  'busty',
#  'gals',
#  'cute',
#  'vest',
#  'great',
#  'top',
#  'ok',
#  'pernette',
#  'henley',
#  'stylish',
#  'versatile',
#  'smile',
#  'humid',
#  "summer's",
#  'day',
#  'new',
#  'staple',
#  'wardrobe',
#  'runs',
#  'short',
#  'feminine',
#  'alternative',
#  'shapeless',
#  'puffer',
#  'love',
#  'love',
#  'love',
#  'skirt',
#  'pretry',
#  'top',
#  'great',
#  'classic',
#  'beautiful',
#  'scratchy',
#  'fence',
#  'pretty',
#  'bit',
#  'long',
#  'bigger',
#  'read',
#  'cute',
#  'skirt',
#  'pretty',
#  'beautiful',
#  'skirt',
#  'gorgeous',
#  'skirt',
#  'beautiful',
#  'impressed',
#  'fair',
#  'great',
#  'colors',
#  'beautiful',
#  'colors',
#  'australian',
#  'sizing',
#  'vibrant',
#  'metallic',
#  'sad',
#  'mine',
#  'scratchy',
#  'uncomfortable',
#  'top',
#  'yes',
#  'scratchy',
#  'work',
#  'classy',
#  'cute',
#  'pretty',
#  'pictured',
#  'great',
#  'purchase',
#  'antoher',
#  'beautiful',
#  'maeve',
#  'dress',
#  'fun',
#  'comfy',
#  'adorable',
#  'beautiful',
#  'fabric',
#  'style',
#  'great',
#  'summer',
#  'wonderful',
#  'going',
#  'back',
#  'comfy',
#  'casual',
#  'shirt',
#  'perfect',
#  'casual',
#  'sweater',
#  'perfect',
#  'warmer',
#  'climates',
#  'need',
#  'petite',
#  'fun',
#  'completes',
#  'many',
#  'outfits',
#  'size',
#  'pictured',
#  'fits',
#  'strange',
#  'flimsy',
#  'material',
#  'nice',
#  'color',
#  'love',
#  'snap',
#  'buttons',
#  'modern',
#  'comfort',
#  'gorgeous',
#  'runs',
#  'small',
#  'pretty',
#  'nice',
#  'thin',
#  'lovely',
#  'feminine',
#  'great',
#  'piece',
#  'love',
#  'everything',
#  'skirt',
#  'perfect',
#  'comfy',
#  'top',
#  'poor',
#  'quality',
#  'huuuuge',
#  'worth',
#  'cost',
#  'tunic',
#  'look',
#  'like',
#  'covering',
#  'big',
#  'runs',
#  'small',
#  'bad',
#  'skirt',
#  'dimensions',
#  'comfort',
#  'style',
#  'classic',
#  'new',
#  'favorite',
#  'dress',
#  'pictured',
#  'autumn',
#  'fever',
#  'small',
#  'cute',
#  'pass',
#  'falling',
#  'goddess',
#  'pretty',
#  'comfy',
#  'perfect',
#  'skirt',
#  'easy',
#  'comfy',
#  'cute',
#  'gorgeous',
#  'pretty',
#  'great',
#  'crop',
#  'pant',
#  'cute',
#  'long',
#  'runs',
#  'large',
#  'bohemian',
#  'wonderful',
#  'weight',
#  'summer',
#  'flattering',
#  'light',
#  'large',
#  'must',
#  'right',
#  'trend',
#  'still',
#  'classic',
#  'pretty',
#  'runs',
#  'large',
#  'comfortable',
#  'stylish',
#  'crop',
#  'pants',
#  'cozy',
#  'sunday',
#  'expected',
#  'fun',
#  'change',
#  'norm',
#  'perfect',
#  'mediterenian',
#  'summer',
#  'loved',
#  'washed',
#  'twice',
#  'fell',
#  'apart',
#  'super',
#  'flattering',
#  'recommend',
#  'love',
#  'cute',
#  'small',
#  'really',
#  'nice',
#  'sweater',
#  'coat',
#  'perfect',
#  'cute',
#  'top',
#  'super',
#  'cute',
#  'pants',
#  'cute',
#  'casual',
#  'dress',
#  'runs',
#  'big',
#  'stylish',
#  'understated',
#  'elegant',
#  'pockets',
#  'fits',
#  'like',
#  'maternity',
#  'top',
#  'love',
#  'top',
#  'love',
#  'coat',
#  'adorable',
#  'flattering',
#  'cute',
#  'go',
#  'pretty',
#  'denim',
#  'jacket',
#  'amazing',
#  'peach',
#  'color',
#  'perfection',
#  'nice',
#  'quality',
#  'short',
#  'tall',
#  'frame',
#  'cute',
#  'top',
#  'back',
#  'jersey',
#  'material',
#  'nice',
#  'color',
#  'perfect',
#  'jean',
#  'jacket',
#  'great',
#  'asset',
#  'gorgeous',
#  'comfy',
#  'fun',
#  'great',
#  'tee',
#  'pretty',
#  'feminine',
#  'sooooooooo',
#  'cute',
#  'peplum',
#  'hem',
#  'tee',
#  'comfortable',
#  'chic',
#  'perfect',
#  'sweatshirt',
#  'clever',
#  'white',
#  'edges',
#  'love',
#  'dress',
#  'much',
#  'structure',
#  'boxy',
#  'almost',
#  'perfect',
#  'denim',
#  'jacket',
#  'perfect',
#  'super',
#  'nice',
#  'wish',
#  'alless',
#  'stiff',
#  'denim',
#  'runs',
#  'small',
#  'terrific',
#  'denim',
#  'jacket',
#  'cute',
#  'versatile',
#  'culottes',
#  'new',
#  'favorite',
#  'denim',
#  'jacket',
#  'favorite',
#  'jean',
#  'jacket',
#  'perfect',
#  'denim',
#  'jacket',
#  'best',
#  'dress',
#  'ever',
#  'stylish',
#  'jacket',
#  'adorable',
#  'stunning',
#  'flattering',
#  'versatile',
#  'pretty',
#  'blouse',
#  'distressed',
#  'stunning',
#  'cute',
#  'top',
#  'runs',
#  'large',
#  'zipper',
#  'sticks',
#  'unflattering',
#  'adorable',
#  'work',
#  'beautiful',
#  'top',
#  'love',
#  'blouse',
#  'lovely',
#  'printed',
#  'blouse',
#  'love',
#  'love',
#  'love',
#  'loveee',
#  'favorite',
#  'new',
#  'blouse',
#  'standout',
#  'lovely',
#  'disappointing',
#  'better',
#  'person',
#  'cuter',
#  'person',
#  'airy',
#  'flattering',
#  'awkward',
#  'fit',
#  'beautiful',
#  'color',
#  'really',
#  'good',
#  'quality',
#  'tee',
#  'cute',
#  'top',
#  'good',
#  'fit',
#  'cutest',
#  'vest',
#  'beautiful',
#  'vintage',
#  'feel',
#  'delicate',
#  'beadwork',
#  'interesting',
#  'design',
#  'fun',
#  'flowy',
#  'beautiful',
#  'shirt',
#  'beautiful',
#  'fabric',
#  'nice',
#  'basic',
#  'piece',
#  'get',
#  'lot',
#  'wear',
#  'soft',
#  'patterned',
#  'long',
#  'vest',
#  'great',
#  'piece',
#  'beautiful',
#  'timeless',
#  'cute',
#  'top',
#  'disappointed',
#  'please',
#  'fix',
#  'ruffled',
#  'buttondown',
#  'exquisite',
#  'blouse',
#  'runs',
#  'huge',
#  'sweater',
#  'coat',
#  'soft',
#  'sweater',
#  'could',
#  'cute',
#  'worth',
#  'sale',
#  'price',
#  'almost',
#  'quite',
#  'nice',
#  'runs',
#  'small',
#  'short',
#  'amazing',
#  'sweatercoat',
#  'great',
#  'piece',
#  'layering',
#  'cute',
#  'nice',
#  'thin',
#  'sweatshirt',
#  'special',
#  'lauer',
#  'comfy',
#  'cute',
#  'looks',
#  'better',
#  'tried',
#  'cute',
#  'romantic',
#  'print',
#  'elegant',
#  'beautiful',
#  'love',
#  'positively',
#  'agree',
#  'love',
#  'print',
#  'style',
#  'cool',
#  'modern',
#  'black',
#  'white',
#  'subdued',
#  'sexy',
#  'sexy',
#  'okay',
#  'one',
#  'favorite',
#  'pieces',
#  'night',
#  'elegant',
#  'eye',
#  'catching',
#  'work',
#  'appropriate',
#  'lace',
#  'poor',
#  'quality',
#  'soft',
#  'cozy',
#  'looks',
#  'deceiving',
#  'terrific',
#  'sweater',
#  'great',
#  'detail',
#  'runs',
#  'large',
#  'pretty',
#  'different',
#  'style',
#  'poorly',
#  'executed',
#  'beautiful',
#  'great',
#  'leggings',
#  'bad',
#  'quality',
#  'flattering',
#  'fun',
#  'love',
#  'love',
#  'love',
#  'lovely',
#  'fabric',
#  'tiny',
#  'hips',
#  'lovely',
#  'dress',
#  'small',
#  'top',
#  'different',
#  'color',
#  'big',
#  'soft',
#  'sure',
#  'one',
#  'comfy',
#  'made',
#  'last',
#  'loving',
#  'jeans',
#  'lovely',
#  'runs',
#  'big',
#  'possibly',
#  'cutest',
#  'skirt',
#  'ever',
#  'classic',
#  'sweet',
#  'little',
#  'top',
#  'comfortable',
#  'dressy',
#  'best',
#  'quality',
#  'soft',
#  'feminine',
#  'versatile',
#  'stylish',
#  'option',
#  'good',
#  'petites',
#  'sweet',
#  'casual',
#  'perfect',
#  'investment',
#  'dress',
#  'gorgeous',
#  'great',
#  'dress',
#  'rough',
#  'zipper',
#  'cute',
#  'comfy',
#  'top',
#  'flattering',
#  'great',
#  'buy',
#  'sale',
#  'love',
#  'shirt',
#  'flimsy',
#  'super',
#  'comfy',
#  'pretty',
#  'pattern',
#  'weird',
#  'fit',
#  'easy',
#  'stylish',
#  'versatile',
#  'small',
#  'boobies',
#  'love',
#  'lace',
#  'design',
#  'disappointed',
#  'chic',
#  'beautiful',
#  'versatile',
#  'top',
#  'pretty',
#  'soft',
#  'great',
#  'work',
#  'fun',
#  'perfect',
#  'shirt',
#  'work',
#  'night',
#  'flattering',
#  'tee',
#  'soft',
#  'comfy',
#  'fit',
#  'yoga',
#  'funky',
#  'classy',
#  'really',
#  'cute',
#  'love',
#  'jacket',
#  'bunches',
#  'weirdly',
#  'front',
#  'cute',
#  'top',
#  'red',
#  'tee',
#  'undecided',
#  'great',
#  'casual',
#  'shirt',
#  'much',
#  'better',
#  'irl',
#  'ultimately',
#  'unimpressed',
#  'vibrant',
#  'red',
#  'color',
#  'love',
#  'looks',
#  'fine',
#  'move',
#  'arms',
#  'great',
#  'plaid',
#  'love',
#  'shirt',
#  'perfection',
#  'perfect',
#  'comfortable',
#  'pants',
#  'ever',
#  'perfect',
#  'top',
#  'work',
#  'overall',
#  'like',
#  'sizing',
#  'issues',
#  'pretty',
#  'boho',
#  'chic',
#  'great',
#  'women',
#  'large',
#  'bust',
#  'cute',
#  'slip',
#  'body',
#  'hugging',
#  'lovely',
#  'romantic',
#  'blouse',
#  'extra',
#  'fabric',
#  'back',
#  'adds',
#  'lot',
#  'great',
#  'sweater',
#  'dress',
#  'pretty',
#  'blouse',
#  'love',
#  'love',
#  'flattering',
#  'dress',
#  'cute',
#  'cheap',
#  'love',
#  'gorgeous',
#  'top',
#  'hint',
#  'pizazz',
#  'else',
#  'lingerie',
#  'jardin',
#  'silk',
#  'bralette',
#  'review',
#  'super',
#  'cute',
#  'flattering',
#  'poor',
#  'quality',
#  'fun',
#  'dress',
#  'cute',
#  'jacket',
#  'cute',
#  'large',
#  'great',
#  'size',
#  'busty',
#  'pretty',
#  'adn',
#  'flattering',
#  'love',
#  'everything',
#  'htis',
#  'dress',
#  'manette',
#  'clipdot',
#  'blouse',
#  'runs',
#  'large',
#  'fun',
#  'mix',
#  'colors',
#  'grey',
#  'version',
#  'pretty',
#  'great',
#  'style',
#  'retailer',
#  'like',
#  'used',
#  'lovely',
#  'cute',
#  'jacket',
#  'shorter',
#  'girls',
#  'flattering',
#  'comfortable',
#  'still',
#  'love',
#  'even',
#  'pretty',
#  'spring',
#  'flowers',
#  'boxy',
#  'cute',
#  'concept',
#  'fits',
#  'weird',
#  'nice',
#  'short',
#  'pretty',
#  'top',
#  'work',
#  'days',
#  'love',
#  'dress',
#  'itchytown',
#  'feminine',
#  'flattering',
#  'versatile',
#  'cute',
#  'weird',
#  'fit',
#  'awesome',
#  'top',
#  'comfy',
#  'cute',
#  'colorful',
#  'best',
#  'fitting',
#  'dress',
#  ...]

# %%
# 출력 사이즈를 설정합니다.
plt.rcParams['figure.figsize'] = (16, 16)

# wordcloud를 저장합니다.
wordcloud = WordCloud(max_font_size=50, max_words=100,background_color="white").generate(' '.join(filtered_sentence))
#join으로 ' ' 한칸 띄어서 연결 시켜줌
# wordcloud를 출력합니다.
plt.imshow(wordcloud,interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
# findall 함수를 사용하여 띄어 쓰기 단위로 글자만을 가져옵니다.(소문자로 변환도 수행)
tokens = re.findall("[\w']+", df_clean['Review Text'].str.lower().str.cat(sep=' ')) 

# tokens에서 'stopwords'에 해당되지 않는 단어를 골라내어 filtered_sentence에 저장합니다.
filtered_sentence = [token for token in tokens if not token in en_stops]
filtered_sentence
# Out:
# ['absolutely',
#  'wonderful',
#  'silky',
#  'sexy',
#  'comfortable',
#  'love',
#  'dress',
#  'sooo',
#  'pretty',
#  'happened',
#  'find',
#  'store',
#  "i'm",
#  'glad',
#  'bc',
#  'never',
#  'would',
#  'ordered',
#  'online',
#  'bc',
#  'petite',
#  'bought',
#  'petite',
#  "5'8",
#  'love',
#  'length',
#  'hits',
#  'little',
#  'knee',
#  'would',
#  'definitely',
#  'true',
#  'midi',
#  'someone',
#  'truly',
#  'petite',
#  'high',
#  'hopes',
#  'dress',
#  'really',
#  'wanted',
#  'work',
#  'initially',
#  'ordered',
#  'petite',
#  'small',
#  'usual',
#  'size',
#  'found',
#  'outrageously',
#  'small',
#  'small',
#  'fact',
#  'could',
#  'zip',
#  'reordered',
#  'petite',
#  'medium',
#  'ok',
#  'overall',
#  'top',
#  'half',
#  'comfortable',
#  'fit',
#  'nicely',
#  'bottom',
#  'half',
#  'tight',
#  'layer',
#  'several',
#  'somewhat',
#  'cheap',
#  'net',
#  'layers',
#  'imo',
#  'major',
#  'design',
#  'flaw',
#  'net',
#  'layer',
#  'sewn',
#  'directly',
#  'zipper',
#  'c',
#  'love',
#  'love',
#  'love',
#  'jumpsuit',
#  'fun',
#  'flirty',
#  'fabulous',
#  'every',
#  'time',
#  'wear',
#  'get',
#  'nothing',
#  'great',
#  'compliments',
#  'shirt',
#  'flattering',
#  'due',
#  'adjustable',
#  'front',
#  'tie',
#  'perfect',
#  'length',
#  'wear',
#  'leggings',
#  'sleeveless',
#  'pairs',
#  'well',
#  'cardigan',
#  'love',
#  'shirt',
#  'love',
#  'tracy',
#  'reese',
#  'dresses',
#  'one',
#  'petite',
#  '5',
#  'feet',
#  'tall',
#  'usually',
#  'wear',
#  '0p',
#  'brand',
#  'dress',
#  'pretty',
#  'package',
#  'lot',
#  'dress',
#  'skirt',
#  'long',
#  'full',
#  'overwhelmed',
#  'small',
#  'frame',
#  'stranger',
#  'alterations',
#  'shortening',
#  'narrowing',
#  'skirt',
#  'would',
#  'take',
#  'away',
#  'embellishment',
#  'garment',
#  'love',
#  'color',
#  'idea',
#  'style',
#  'work',
#  'returned',
#  'dress',
#  'aded',
#  'basket',
#  'hte',
#  'last',
#  'mintue',
#  'see',
#  'would',
#  'look',
#  'like',
#  'person',
#  'store',
#  'pick',
#  'went',
#  'teh',
#  'darkler',
#  'color',
#  'pale',
#  'hte',
#  'color',
#  'really',
#  'gorgeous',
#  'turns',
#  'mathced',
#  'everythiing',
#  'trying',
#  'prefectly',
#  'little',
#  'baggy',
#  'hte',
#  'xs',
#  'hte',
#  'msallet',
#  'size',
#  'bummer',
#  'petite',
#  'decided',
#  'jkeep',
#  'though',
#  'said',
#  'matvehd',
#  'everything',
#  'ejans',
#  'pants',
#  '3',
#  'skirts',
#  'waas',
#  'trying',
#  'kept',
#  'oops',
#  'ordered',
#  'carbon',
#  'store',
#  'pick',
#  'ton',
#  'stuff',
#  'always',
#  'try',
#  'used',
#  'top',
#  'pair',
#  'skirts',
#  'pants',
#  'everything',
#  'went',
#  'color',
#  'really',
#  'nice',
#  'charcoal',
#  'shimmer',
#  'went',
#  'well',
#  'pencil',
#  'skirts',
#  'flare',
#  'pants',
#  'etc',
#  'compaint',
#  'bit',
#  'big',
#  'sleeves',
#  'long',
#  'go',
#  'petite',
#  'also',
#  'bit',
#  'loose',
#  'xxs',
#  'kept',
#  'wil',
#  'ldecide',
#  'later',
#  'since',
#  'light',
#  'color',
#  'already',
#  'sold',
#  'hte',
#  'smallest',
#  'size',
#  'love',
#  'dress',
#  'usually',
#  'get',
#  'xs',
#  'runs',
#  'little',
#  'snug',
#  'bust',
#  'ordered',
#  'size',
#  'flattering',
#  'feminine',
#  'usual',
#  'retailer',
#  'flair',
#  'style',
#  "i'm",
#  '5',
#  "5'",
#  '125',
#  'lbs',
#  'ordered',
#  'petite',
#  'make',
#  'sure',
#  'length',
#  'long',
#  'typically',
#  'wear',
#  'xs',
#  'regular',
#  'retailer',
#  'dresses',
#  'less',
#  'busty',
#  '34b',
#  'cup',
#  'smaller',
#  'petite',
#  'fit',
#  'perfectly',
#  'snug',
#  'tight',
#  'love',
#  'could',
#  'dress',
#  'party',
#  'work',
#  'love',
#  'tulle',
#  'longer',
#  'fabric',
#  'underneath',
#  'dress',
#  'runs',
#  'small',
#  'esp',
#  'zipper',
#  'area',
#  'runs',
#  'ordered',
#  'sp',
#  'typically',
#  'fits',
#  'tight',
#  'material',
#  'top',
#  'looks',
#  'feels',
#  'cheap',
#  'even',
#  'pulling',
#  'cause',
#  'rip',
#  'fabric',
#  'pretty',
#  'disappointed',
#  'going',
#  'christmas',
#  'dress',
#  'year',
#  'needless',
#  'say',
#  'going',
#  'back',
#  'dress',
#  'perfection',
#  'pretty',
#  'flattering',
#  'find',
#  'reliant',
#  'reviews',
#  'written',
#  'savvy',
#  'shoppers',
#  'past',
#  'right',
#  'estimation',
#  'product',
#  'case',
#  'dress',
#  'reveiws',
#  'doubt',
#  'would',
#  'even',
#  'tried',
#  'dress',
#  'beautifully',
#  'made',
#  'lined',
#  'reminiscent',
#  'old',
#  'retailer',
#  'quality',
#  'lined',
#  'solid',
#  'periwinkle',
#  'colored',
#  'fabric',
#  'matches',
#  'outer',
#  'fabric',
#  'print',
#  'tts',
#  'form',
#  'fitting',
#  'falls',
#  'knee',
#  'rid',
#  'bought',
#  'black',
#  'xs',
#  'go',
#  'larkspur',
#  'midi',
#  'dress',
#  'bother',
#  'lining',
#  'skirt',
#  'portion',
#  'grrrrrrrrrrr',
#  'stats',
#  '34a',
#  '28',
#  '29',
#  '36',
#  'xs',
#  'fit',
#  'smoothly',
#  'around',
#  'chest',
#  'flowy',
#  'around',
#  'lower',
#  'half',
#  'would',
#  'say',
#  'running',
#  'big',
#  'straps',
#  'pretty',
#  'could',
#  'easily',
#  'nightwear',
#  "i'm",
#  "5'6",
#  'came',
#  'knees',
#  'nice',
#  'choice',
#  'holiday',
#  'gatherings',
#  'like',
#  'length',
#  'grazes',
#  'knee',
#  'conservative',
#  'enough',
#  'office',
#  'related',
#  'gatherings',
#  'size',
#  'small',
#  'fit',
#  'well',
#  'usually',
#  'size',
#  '2',
#  '4',
#  'small',
#  'bust',
#  'opinion',
#  'runs',
#  'small',
#  'larger',
#  'busts',
#  'definitely',
#  'size',
#  'perhaps',
#  'waist',
#  'big',
#  'problem',
#  'dress',
#  'quality',
#  'fabrics',
#  'terrible',
#  'delicate',
#  'netting',
#  'type',
#  'fabric',
#  'top',
#  'layer',
#  'skirt',
#  'got',
#  'stuck',
#  'zip',
#  'took',
#  'package',
#  'wanted',
#  'fit',
#  'badly',
#  'could',
#  'tell',
#  'put',
#  'hour',
#  'glass',
#  'figure',
#  'straight',
#  'waist',
#  'way',
#  'small',
#  'body',
#  'shape',
#  'even',
#  'sized',
#  'could',
#  'tell',
#  'would',
#  'still',
#  'tight',
#  'waist',
#  'roomy',
#  'hips',
#  'said',
#  'really',
#  'nice',
#  'sturdy',
#  'linen',
#  'like',
#  'fabric',
#  'pretty',
#  'color',
#  'well',
#  'made',
#  'hope',
#  'make',
#  'someone',
#  'happy',
#  'material',
#  'color',
#  'nice',
#  'leg',
#  'opening',
#  'large',
#  "5'1",
#  '100',
#  'length',
#  'hits',
#  'right',
#  'ankle',
#  'leg',
#  'opening',
#  'size',
#  'waist',
#  'hem',
#  'line',
#  'ankle',
#  'front',
#  'pleats',
#  'make',
#  'fluffy',
#  'think',
#  'imagine',
#  'flattering',
#  'look',
#  'least',
#  'average',
#  'height',
#  'taller',
#  'may',
#  'look',
#  'good',
#  'took',
#  'chance',
#  'blouse',
#  'glad',
#  'crazy',
#  'blouse',
#  'photographed',
#  'model',
#  'paired',
#  'whit',
#  'white',
#  'pants',
#  'worked',
#  'perfectly',
#  'crisp',
#  'clean',
#  'would',
#  'describe',
#  'launders',
#  'well',
#  'fits',
#  'great',
#  'drape',
#  'perfect',
#  'wear',
#  'tucked',
#  "can't",
#  'go',
#  'wrong',
#  'flattering',
#  'super',
#  'cozy',
#  'coat',
#  'work',
#  'well',
#  'cold',
#  'dry',
#  'days',
#  'look',
#  'good',
#  'jeans',
#  'dressier',
#  'outfit',
#  "5'",
#  "5''",
#  '135',
#  'small',
#  'fits',
#  'great',
#  'love',
#  'look',
#  'feel',
#  'tulle',
#  'dress',
#  'looking',
#  'something',
#  'different',
#  'top',
#  'new',
#  "year's",
#  'eve',
#  "i'm",
#  'small',
#  'chested',
#  'top',
#  'dress',
#  'form',
#  'fitting',
#  'flattering',
#  'look',
#  'steamed',
#  'tulle',
#  'perfect',
#  'ordered',
#  'xsp',
#  'length',
#  'perfect',
#  'product',
#  'petite',
#  'would',
#  'get',
#  'petite',
#  'regular',
#  'little',
#  'long',
#  'tailor',
#  'simple',
#  'fix',
#  'fits',
#  'nicely',
#  "i'm",
#  "5'4",
#  '130lb',
#  'pregnant',
#  'bough',
#  'medium',
#  'grow',
#  'tie',
#  'front',
#  'back',
#  'provides',
#  'nice',
#  'flexibility',
#  'form',
#  'fitting',
#  "i'm",
#  'upset',
#  'price',
#  'dress',
#  'thought',
#  'embroidered',
#  'print',
#  'fabric',
#  'think',
#  'cried',
#  'little',
#  'opened',
#  'box',
#  'still',
#  'ver',
#  'pretty',
#  'would',
#  'say',
#  'true',
#  'size',
#  'tad',
#  'bit',
#  'big',
#  'tiny',
#  'still',
#  'get',
#  'away',
#  'color',
#  'vibrant',
#  'style',
#  'unique',
#  'skirt',
#  'portion',
#  'pretty',
#  'poofy',
#  'keep',
#  'going',
#  'back',
#  'forth',
#  'mainly',
#  'price',
#  'although',
#  'quality',
#  'definitely',
#  'except',
#  'wish',
#  'emb',
#  'first',
#  'pullover',
#  'styling',
#  'side',
#  'zipper',
#  'purchased',
#  'knew',
#  'side',
#  'zipper',
#  'large',
#  'bust',
#  'side',
#  'zippers',
#  'next',
#  'impossible',
#  'second',
#  'tulle',
#  'feels',
#  'looks',
#  'cheap',
#  'slip',
#  'awkward',
#  'tight',
#  'shape',
#  'underneath',
#  'looks',
#  'like',
#  'described',
#  'sadly',
#  'returning',
#  "i'm",
#  'sure',
#  'find',
#  'something',
#  'exchange',
#  'cute',
#  'little',
#  'dress',
#  'fits',
#  'tts',
#  'little',
#  'high',
#  'waisted',
#  'good',
#  'length',
#  "5'9",
#  'height',
#  'like',
#  'dress',
#  "i'm",
#  'love',
#  'dont',
#  'think',
#  'looks',
#  'feels',
#  'cheap',
#  'appears',
#  'pictured',
#  'love',
#  'shirt',
#  'first',
#  'saw',
#  'sure',
#  'shirt',
#  'dress',
#  'since',
#  'see',
#  'wear',
#  'like',
#  'dress',
#  'need',
#  'slip',
#  'wear',
#  'leggings',
#  'bought',
#  'slip',
#  'wore',
#  'tie',
#  'back',
#  'rocked',
#  'white',
#  'wedges',
#  'could',
#  'also',
#  'wear',
#  'vest',
#  'careful',
#  'buttons',
#  'fall',
#  'yet',
#  'feel',
#  'like',
#  'overall',
#  'great',
#  'occasion',
#  'fun',
#  'wear',
#  'loved',
#  'material',
#  'didnt',
#  'really',
#  'look',
#  'long',
#  'dress',
#  'purchased',
#  'large',
#  'medium',
#  'im',
#  "5'5",
#  'atleast',
#  '5',
#  'material',
#  'feet',
#  'gaps',
#  'front',
#  'much',
#  'wider',
#  'look',
#  'felt',
#  'like',
#  'dress',
#  'fell',
#  'flat',
#  'returned',
#  'im',
#  'usually',
#  'large',
#  'med',
#  'fit',
#  'better',
#  '36d',
#  '30',
#  'jeans',
#  'waiting',
#  'sweater',
#  'coat',
#  'ship',
#  'weeks',
#  'excited',
#  'arrive',
#  'coat',
#  'true',
#  'size',
#  'made',
#  'look',
#  'short',
#  'squat',
#  'sleeves',
#  'wide',
#  'although',
#  'long',
#  'light',
#  'weight',
#  'fall',
#  'coat',
#  'sleeves',
#  'need',
#  'wide',
#  'layerng',
#  'much',
#  'underneath',
#  'buttons',
#  'need',
#  'moved',
#  'least',
#  'three',
#  'inches',
#  'nicer',
#  'fit',
#  'thought',
#  'redoing',
#  'buttons',
#  'sleeves',
#  'looked',
#  'even',
#  'proportion',
#  'tigh',
#  'colors',
#  'expected',
#  'either',
#  'dark',
#  'blue',
#  'much',
#  'vibrant',
#  'find',
#  'anything',
#  'really',
#  'go',
#  'fabric',
#  'thick',
#  'good',
#  'quality',
#  'nice',
#  'weight',
#  'movement',
#  'skirt',
#  'end',
#  'several',
#  'goodhyouman',
#  'shirts',
#  'get',
#  'many',
#  'compliments',
#  'especially',
#  'one',
#  'says',
#  'forehead',
#  'kisses',
#  'underrated',
#  'hesitate',
#  'buy',
#  'shirt',
#  'sorry',
#  'sweater',
#  'comfy',
#  'classic',
#  'balances',
#  'quirky',
#  'hand',
#  'knit',
#  'look',
#  'beautiful',
#  'color',
#  'practical',
#  'fit',
#  'bit',
#  'cropped',
#  'boxy',
#  'part',
#  'style',
#  'others',
#  'mentioned',
#  'gaps',
#  'knit',
#  'make',
#  'see',
#  'opinion',
#  'makes',
#  'perfect',
#  'layering',
#  'like',
#  'longer',
#  'camisole',
#  'showing',
#  'underneath',
#  'wearing',
#  'little',
#  'dress',
#  'warm',
#  'still',
#  'thin',
#  'enough',
#  'fit',
#  'jacket',
#  'coat',
#  'beautifully',
#  'made',
#  'pants',
#  'trend',
#  'flared',
#  'crop',
#  'much',
#  'cuter',
#  'person',
#  'love',
#  'never',
#  'would',
#  'given',
#  'pants',
#  'second',
#  'look',
#  'online',
#  'person',
#  'much',
#  'cuter',
#  'stripes',
#  'brighter',
#  'fit',
#  'flattering',
#  'crop',
#  'cute',
#  'flare',
#  'right',
#  'trend',
#  'brand',
#  'always',
#  'run',
#  'small',
#  "5'8",
#  '140lbs',
#  'carry',
#  'chubbiness',
#  'belly',
#  'paired',
#  'collarless',
#  'loose',
#  'navy',
#  'blazer',
#  'pants',
#  'even',
#  'better',
#  ...]

# %%
# 출력 사이즈를 설정합니다.
plt.rcParams['figure.figsize'] = (16, 16)

# wordcloud를 저장합니다.
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(' '.join(filtered_sentence))

# wordcloud를 출력합니다.
plt.imshow(wordcloud,interpolation="bilinear")#출력방식
plt.axis("off")
plt.show()

# %%
# 분포를 막대 그래프를 사용하여 출력합니다.
df_clean['Recommended IND'].value_counts().plot(kind='bar')

# 분포를 도수분포표로 확인합니다.
df_clean['Recommended IND'].value_counts()
# Out:
# 0    18540
# 1     4101
# Name: Recommended IND, dtype: int64

# %%
4. 데이터 전 처리
상품 추천 여부 예측을 수행하기 위해서 주어진 이커머스 데이터에 대해서 분류 모델을 사용할 것입니다.

이번 파트에서는 Review Text 데이터만을 사용하여 예측을 수행하지만, age나 Title 데이터 등을 추가하여 입력을 확장할 수 있습니다.

분류 모델의 필요한 입력 데이터를 준비 하기위해서 다음과 같은 전처리를 수행하겠습니다.

Review Text 데이터 자연어 전 처리 - Tfidf 활용
학습 데이터와 테스트 데이터로 나누기
4.1. 자연어 전 처리 - Tfidf
자연어 전 처리는 자연어 데이터를 머신러닝의 입력값으로 사용할 수 있도록 변환하는 과정을 의미합니다. 이번 실습에서는 sklearn에서 제공하는 TfidfVectorizer를 사용하여 문자열 데이터를 수치 자료형 벡터로 변환해 보겠습니다

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# TfidfVectorizer을 불러옵니다. (stop_words 는 영어로 설정)
vectorizer = TfidfVectorizer(stop_words = 'english')

# 소문자화 'Review Text'데이터를 Tfidf로 변환합니다.
X = vectorizer.fit_transform(df_clean['Review Text'].str.lower())

# %%
sample = ['I am studying project subject','I am studying natural language preporcessing']

sample_vectorizer = TfidfVectorizer(stop_words = 'english')# I 랑 am 삭제 불용어 제거

sample_matrix = sample_vectorizer.fit_transform(sample)

# %%
sample_vectorizer.vocabulary_
# Out:
# {'studying': 4,
#  'project': 3,
#  'subject': 5,
#  'natural': 1,
#  'language': 0,
#  'preporcessing': 2}

# %%
sample_matrix[0].toarray()
#위에 생성된 단어장 기준으로 첫번째 문장과 비교해서 빈도수를 표현 단 자주 채용되면 중요도가 떨어짐 
#studying이 두 문장에 모두 있기때문에 중요도가 떨어져서 0.4 나옴
# Out:
# array([[0.        , 0.        , 0.        , 0.6316672 , 0.44943642,
#         0.6316672 ]])

# %%
# 변환된 X의 크기를 살펴봅니다.
X.shape
#22641개의 문장을 13855의 단어장으로 만듬
# Out:
# (22641, 13855)

# %%
# 예측해야 할 변수 'Recommended IND' 만을 선택하여 numpy 형태로 y에 저장합니다.
y = df_clean['Recommended IND']
y = y.to_numpy().ravel() # 1 차원 벡터 형태로 출력하기 위해 ravel 사용

# %%
y
# Out:
# array([0, 0, 1, ..., 1, 0, 0], dtype=int64)

# %%
vectorizer.get_feature_names()
#단어 사전에 단어만 출력
# Out:
# C:\Users\gotsl\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['00',
#  '000',
#  '00p',
#  '02',
#  '03',
#  '03dd',
#  '04',
#  '06',
#  '0dd',
#  '0in',
#  '0p',
#  '0petite',
#  '0r',
#  '0verall',
#  '0xs',
#  '10',
#  '100',
#  '1000',
#  '100lb',
#  '100lbs',
#  '101',
#  '102',
#  '102lbs',
#  '103',
#  '103lb',
#  '103lbs',
#  '104',
#  '104lbs',
#  '105',
#  '105lb',
#  '105lbs',
#  '106',
#  '106lbs',
#  '107',
#  '107lb',
#  '107lbs',
#  '107pound',
#  '108',
#  '108lbs',
#  '109',
#  '109lbs',
#  '10l',
#  '10lbs',
#  '10mths',
#  '10p',
#  '10s',
#  '10th',
#  '10x',
#  '11',
#  '110',
#  '110lb',
#  '110lbs',
#  '111',
#  '111lbs',
#  '112',
#  '112lb',
#  '112lbs',
#  '112llbs',
#  '113',
#  '113lbs',
#  '114',
#  '114lb',
#  '114lbs',
#  '115',
#  '115ish',
#  '115lb',
#  '115lbs',
#  '115llbs',
#  '116',
#  '116bs',
#  '116ibs',
#  '116lb',
#  '116lbs',
#  '117',
#  '117bl',
#  '117lbs',
#  '118',
#  '118lb',
#  '118lbs',
#  '119',
#  '11and',
#  '11in',
#  '11inches',
#  '12',
#  '120',
#  '120lb',
#  '120lbs',
#  '121',
#  '122',
#  '122lb',
#  '122lbs',
#  '123',
#  '123lb',
#  '123lbs',
#  '123lbssize',
#  '124',
#  '124lb',
#  '124lbs',
#  '125',
#  '125b',
#  '125ibs',
#  '125ish',
#  '125lb',
#  '125lbs',
#  '126',
#  '126lbs',
#  '127',
#  '127lb',
#  '127lbs',
#  '128',
#  '128b',
#  '128lb',
#  '128lbs',
#  '129',
#  '129lbs',
#  '12p',
#  '12th',
#  '13',
#  '130',
#  '130b',
#  '130ibs',
#  '130l',
#  '130lb',
#  '130lbs',
#  '130pounds',
#  '132',
#  '132lbs',
#  '133',
#  '133lbs',
#  '134',
#  '134b',
#  '134lb',
#  '134lbs',
#  '135',
#  '135lb',
#  '135lbs',
#  '136',
#  '136lb',
#  '136lbs',
#  '137',
#  '137lbs',
#  '138',
#  '138lbs',
#  '139',
#  '13th',
#  '14',
#  '140',
#  '140b',
#  '140ish',
#  '140lb',
#  '140lbs',
#  '141',
#  '142',
#  '142lbs',
#  '143',
#  '143lb',
#  '143lbs',
#  '144',
#  '144lb',
#  '144lbs',
#  '145',
#  '145lb',
#  '145lbs',
#  '146',
#  '146lbs',
#  '147',
#  '148',
#  '148lbs',
#  '149',
#  '149lbs',
#  '14p',
#  '14s',
#  '15',
#  '150',
#  '150lb',
#  '150lbs',
#  '152',
#  '153',
#  '154',
#  '154lbs',
#  '155',
#  '155lb',
#  '155lbs',
#  '156',
#  '157',
#  '158',
#  '16',
#  '160',
#  '160lb',
#  '160lbs',
#  '165',
#  '165lb',
#  '165lbs',
#  '167',
#  '168',
#  '16s',
#  '17',
#  '170',
#  '170lbs',
#  '172lbs',
#  '174',
#  '175',
#  '175lbs',
#  '178',
#  '18',
#  '180',
#  '180lb',
#  '180lbs',
#  '183lbs',
#  '185',
#  '18th',
#  '19',
#  '190',
#  '190lbs',
#  '1920',
#  '1920s',
#  '1930',
#  '1940',
#  '1940s',
#  '1950',
#  '1950s',
#  '195lbs',
#  '1960s',
#  '1970',
#  '1970s',
#  '1973',
#  '198',
#  '1980s',
#  '1982',
#  '1987',
#  '1988',
#  '1990',
#  '1990s',
#  '1993',
#  '1st',
#  '1x',
#  '20',
#  '200',
#  '2000',
#  '2000s',
#  '2001',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2010',
#  '2012',
#  '2013',
#  '2015',
#  '2016',
#  '2017',
#  '2035',
#  '20lb',
#  '20lbs',
#  '20s',
#  '20th',
#  '20x',
#  '21',
#  '218',
#  '22',
#  '220lbs',
#  '228',
#  '23',
#  '230lbs',
#  '23b',
#  '24',
#  '24p',
#  '24s',
#  '24th',
#  '25',
#  '250',
#  '251',
#  '25p',
#  '25petite',
#  '25s',
#  '25th',
#  '26',
#  '26p',
#  '26r',
#  '26s',
#  '26tall',
#  '27',
#  '27in',
#  '27inches',
#  '27p',
#  '27r',
#  '27s',
#  '27tall',
#  '28',
#  '28dd',
#  '28dddd',
#  '28l',
#  '28p',
#  '28r',
#  '28s',
#  '28t',
#  '29',
#  '29p',
#  '29s',
#  '2fit',
#  '2in',
#  '2inches',
#  '2nd',
#  '2p',
#  '2petite',
#  '2r',
#  '2regular',
#  '2s',
#  '2x',
#  '30',
#  '300',
#  '3000',
#  '30aa',
#  '30b',
#  '30d',
#  '30dd',
#  '30ddd',
#  '30e',
#  '30f',
#  '30g',
#  '30gg',
#  '30in',
#  '30inch',
#  '30lbs',
#  '30p',
#  '30percent',
#  '30s',
#  '30ss',
#  '30th',
#  '31',
#  '31p',
#  '31st',
#  '32',
#  '32a',
#  '32b',
#  '32c',
#  '32d',
#  '32dd',
#  '32ddd',
#  '32e',
#  '32f',
#  '32g',
#  '32h',
#  '32nd',
#  '32p',
#  '32s',
#  '33',
#  '33a',
#  '33b',
#  '33d',
#  '34',
#  '34a',
#  '34aa',
#  '34b',
#  '34c',
#  '34d',
#  '34dd',
#  '34ddd',
#  '34dddd',
#  '34ds',
#  '34e',
#  '34f',
#  '34ff',
#  '34g',
#  '35',
#  '35a',
#  '35ab',
#  '35c',
#  '35x27x36',
#  '35x28x39',
#  '36',
#  '368',
#  '36a',
#  '36aa',
#  '36b',
#  '36c',
#  '36d',
#  '36dd',
#  '36ddd',
#  '36dddd',
#  '36dds',
#  '36e',
#  '36g',
#  '36h',
#  '36j',
#  '37',
#  '37ish',
#  '38',
#  '38b',
#  '38c',
#  '38d',
#  '38dd',
#  '38dds',
#  '38f',
#  '38in',
#  '38inch',
#  '38ish',
#  '39',
#  '39ish',
#  '3c',
#  '3d',
#  '3hr',
#  '3in',
#  '3inches',
#  '3ish',
#  '3rd',
#  '3rds',
#  '3was',
#  '3x',
#  '3xl',
#  '3xs',
#  '3xxxl',
#  '40',
#  '400',
#  '40c',
#  '40d',
#  '40dd',
#  '40s',
#  '40something',
#  '40th',
#  '40yo',
#  '41',
#  '4115',
#  '42',
#  '428',
#  '42dd',
#  '43',
#  '44',
#  '448',
#  '45',
#  '450',
#  '46',
#  '47',
#  '48',
#  '49',
#  '4am',
#  '4d',
#  '4fits',
#  '4ft',
#  '4in',
#  '4inches',
#  '4l',
#  '4p',
#  '4petite',
#  '4r',
#  '4th',
#  '4yrs',
#  '50',
#  '500',
#  '501',
#  '50s',
#  '50th',
#  '51',
#  '52',
#  '53',
#  '54',
#  '55',
#  '56',
#  '57',
#  '58',
#  '59',
#  '5ft',
#  '5ft2in',
#  '5ft3in',
#  '5ft4',
#  '5ft7',
#  '5ft8inches',
#  '5in',
#  '5lbs',
#  '5mo',
#  '5star',
#  '5stars',
#  '5th',
#  '60',
#  '60s',
#  '60th',
#  '61',
#  '62',
#  '63',
#  '64',
#  '65',
#  '66',
#  '67',
#  '68',
#  '69',
#  '6am',
#  '6ft',
#  '6in',
#  '6inches',
#  '6p',
#  '6petite',
#  '6r',
#  '6s',
#  '6t',
#  '6th',
#  '70',
#  '70s',
#  '73',
#  '75',
#  '78',
#  '79',
#  '7in',
#  '7months',
#  '80',
#  '800',
#  '80f',
#  '80s',
#  '83',
#  '84',
#  '85',
#  '86',
#  '88',
#  '89',
#  '8in',
#  '8p',
#  '8petite',
#  '8s',
#  '8yo',
#  '90',
#  '90s',
#  '92',
#  '92lbs',
#  '95',
#  '95lb',
#  '95lbs',
#  '96',
#  '97',
#  '98',
#  '98lbs',
#  '99',
#  '9between',
#  '9inches',
#  '9lower',
#  '______',
#  '_______',
#  '________',
#  '_________',
#  '__________',
#  '___________',
#  '____________',
#  '_____________',
#  '______________',
#  '_______________',
#  '_________________',
#  '__________________',
#  '______________________',
#  'a0',
#  'a32',
#  'a34b',
#  'a9dn',
#  'aa',
#  'aaaaaaamazing',
#  'aaaaandidon',
#  'aaaaannnnnnd',
#  'aaaahmazing',
#  'aaaahs',
#  'aaahed',
#  'aame',
#  'ab',
#  'abbey',
#  'abby',
#  'abck',
#  'abdomen',
#  'abdominal',
#  'abercrombie',
#  'abhor',
#  'ability',
#  'abject',
#  'able',
#  'abnormal',
#  'abnormally',
#  'abo',
#  'abolutely',
#  'abou',
#  'abroad',
#  'abruptly',
#  'abs',
#  'absence',
#  'abso',
#  'absolute',
#  'absolutely',
#  'absolutley',
#  'absolutly',
#  'absoluty',
#  'absorbent',
#  'abstract',
#  'absurd',
#  'absurdly',
#  'abt',
#  'abundance',
#  'abundant',
#  'abused',
#  'abut',
#  'ac',
#  'acacia',
#  'accent',
#  'accented',
#  'accenting',
#  'accents',
#  'accentuate',
#  'accentuatea',
#  'accentuated',
#  'accentuates',
#  'accentuating',
#  'accept',
#  'acceptabl',
#  'acceptable',
#  'acceptably',
#  'accepted',
#  'accepts',
#  'access',
#  'accesso',
#  'accessories',
#  'accessorize',
#  'accessorized',
#  'accessorizer',
#  'accessorizes',
#  'accessorizing',
#  'accessory',
#  'accident',
#  'accidental',
#  'accidentally',
#  'accidents',
#  'acco',
#  'accomadate',
#  'accommodate',
#  'accommodated',
#  'accommodates',
#  'accommodating',
#  'accomodate',
#  'accompanies',
#  'accompany',
#  'accompanying',
#  'accomplish',
#  'accomplishing',
#  'accomplishment',
#  'accord',
#  'accordance',
#  'accordian',
#  'according',
#  'accordingly',
#  'accordion',
#  'account',
#  'accounts',
#  'accumulate',
#  'accuracy',
#  'accurate',
#  'accurately',
#  'ace',
#  'acetate',
#  'achieve',
#  'achieved',
#  'acid',
#  'ack',
#  'acknowledge',
#  'acquaintance',
#  'acquiring',
#  'acquisition',
#  'acrossed',
#  'acrylic',
#  'act',
#  'action',
#  'active',
#  'actively',
#  'activewear',
#  'activities',
#  'activity',
#  'acts',
#  'actual',
#  'actuality',
#  'actuallly',
#  'actually',
#  'actualyl',
#  'acutually',
#  'ad',
#  'ada',
#  'add',
#  'added',
#  'addict',
#  'addicted',
#  'addiction',
#  'adding',
#  'addit',
#  'additio',
#  'addition',
#  'additional',
#  'additionally',
#  'additonal',
#  'address',
#  'addressed',
#  'adds',
#  'addtl',
#  'aded',
#  'adequate',
#  'adequately',
#  'adhesive',
#  'adieu',
#  'adirondacks',
#  'adj',
#  'adjacent',
#  'adjsut',
#  'adjust',
#  'adjustability',
#  'adjustable',
#  'adjusted',
#  'adjusting',
#  'adjustment',
#  'adjustments',
#  'adjusts',
#  'admirable',
#  'admiration',
#  'admire',
#  'admired',
#  'admirin',
#  'admiring',
#  'admit',
#  'admittedly',
#  'adn',
#  'adopted',
#  'ador',
#  'adorable',
#  'adorably',
#  'adore',
#  'adoreable',
#  'adored',
#  'adores',
#  'adoring',
#  'adorn',
#  'adorned',
#  'ads',
#  'adult',
#  'adults',
#  'advantage',
#  'advantages',
#  'adventure',
#  'adventurous',
#  'advertise',
#  'advertised',
#  'advertisement',
#  'advertising',
#  'advice',
#  'advise',
#  'advised',
#  'advises',
#  'advising',
#  'aesthetic',
#  'aesthetically',
#  'aesthetics',
#  'affair',
#  'affect',
#  'affected',
#  'affects',
#  'affixed',
#  'affluent',
#  'afford',
#  'affordable',
#  'afforded',
#  'affords',
#  'afghan',
#  'aforementioned',
#  'afraid',
#  'africa',
#  'aft',
#  'afterall',
#  'afternoon',
#  'afterthought',
#  'afterward',
#  'afterwork',
#  'ag',
#  'aga',
#  'agai',
#  'age',
#  'aged',
#  'ageing',
#  'ageless',
#  'agent',
#  'ages',
#  'aggressive',
#  'aggressively',
#  'aghast',
#  'agin',
#  'agitated',
#  'agitates',
#  'ago',
#  'agree',
#  'agreed',
#  'agreeing',
#  'agreement',
#  'agrees',
#  'ags',
#  'agustable',
#  'ah',
#  'ahd',
#  'ahe',
#  'ahead',
#  'ahem',
#  'ahge',
#  'ahh',
#  'ahhh',
#  'ahhhh',
#  'ahold',
#  'aholed',
#  'ahs',
#  'ahtro',
#  'ahve',
#  'ai',
#  'aid',
#  'aided',
#  'aiming',
#  'air',
#  'airflow',
#  'airier',
#  'airiness',
#  'airing',
#  'airism',
#  'airline',
#  'airly',
#  'airplane',
#  'airplanes',
#  'airport',
#  'airy',
#  'airyness',
#  'aize',
#  'aka',
#  'akemi',
#  'akin',
#  'akward',
#  'al',
#  'alas',
#  'alaska',
#  'albeit',
#  'alce',
#  'aleardy',
#  'alerations',
#  'alert',
#  'alerted',
#  'alexa',
#  'alexandria',
#  'ali',
#  'align',
#  'aligned',
#  'aligning',
#  'alignment',
#  'alike',
#  'aline',
#  'alined',
#  'alining',
#  'alittle',
#  'allergic',
#  'allergies',
#  'alleviate',
#  'alleviated',
#  'alley',
#  'allison',
#  'alllll',
#  'allllllmost',
#  'allot',
#  'allover',
#  'allow',
#  'allowance',
#  'allowed',
#  'allowing',
#  'allows',
#  'alls',
#  'alludes',
#  'alluring',
#  'allusion',
#  'allusione',
#  'allways',
#  'almsot',
#  'alot',
#  'alpaca',
#  'alr',
#  'alrea',
#  'alread',
#  'alright',
#  'als',
#  'alst',
#  'alt',
#  'altar',
#  'alter',
#  'alteration',
#  'alterations',
#  'altered',
#  'altering',
#  'alternate',
#  'alternately',
#  'alternations',
#  'alternative',
#  'althetic',
#  'althleisure',
#  'altho',
#  'alto',
#  'altogether',
#  'alway',
#  'am5',
#  'ama',
#  'amadi',
#  'amalfi',
#  'amaz',
#  'amaze',
#  'amazed',
#  'amazement',
#  'amazing',
#  'amazingly',
#  'amazon',
#  'amber',
#  'ambiguous',
#  'ambitious',
#  'amd',
#  'amelia',
#  'amenable',
#  'american',
#  'amidst',
#  'amking',
#  'amoret',
#  'amorphous',
#  'amost',
#  'amounts',
#  'amp',
#  'ample',
#  'amply',
#  'amputated',
#  'amsterdam',
#  'amt',
#  'amterial',
#  'anafa',
#  'analogy',
#  'analysis',
#  'anatomy',
#  'anchors',
#  'andddddd',
#  'andheavy',
#  'andrews',
#  'androgynous',
#  'ands',
#  'ang',
#  'angel',
#  'angela',
#  'angeles',
#  'angelinas',
#  'angels',
#  'angle',
#  'angled',
#  'angles',
#  'angling',
#  'angora',
#  'anhtro',
#  'animal',
#  'animals',
#  'anita',
#  'ankl',
#  'ankle',
#  'ankles',
#  'anlobn',
#  'ann',
#  'anna',
#  'annie',
#  'anniversary',
#  'annnnd',
#  'announce',
#  'annoy',
#  'annoyance',
#  'annoyed',
#  'annoying',
#  'annoyingly',
#  'annoys',
#  'annual',
#  'anomaly',
#  'anorak',
#  'anorexic',
#  'anoth',
#  'anothe',
#  'anothr',
#  'anrtho',
#  'ans',
#  'answe',
#  'answer',
#  'ansy',
#  'ant',
#  'ante',
#  'antebellum',
#  'anth',
#  'anther',
#  'antheropologie',
#  'anthletic',
#  'antho',
#  'anthopology',
#  'anthto',
#  'anti',
#  'anticipate',
#  'anticipated',
#  'anticipating',
#  'anticipation',
#  'anticpated',
#  'antique',
#  'antrho',
#  'antrhopologie',
#  'antro',
#  ...]

# %%
from sklearn.model_selection import train_test_split

# sklearn에서 제공하는 train_test_split을 사용하여 손 쉽게 분리 할 수 있습니다.
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.tree import DecisionTreeClassifier

# 의사결정나무 DecisionTreeClassifier class를 가져 옵니다.
model = DecisionTreeClassifier()

# fit 함수를 사용하여 데이터를 학습합니다.
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# score 함수를 사용하여 모델의 성능을 출력합니다. 오버피팅
print(model.score(x_train, y_train))
print(model.score(x_test, y_test))
# Out:
# 1.0
# 0.8072422168249062

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
import xgboost as xgb
from xgboost.sklearn import XGBClassifier


models = []
models.append(('KNN', KNeighborsClassifier()))  # KNN 모델 거리기반
models.append(('NB-M', MultinomialNB()))  # 멀티노미얼 나이브 베이즈  확률 기반
models.append(('NB-B', BernoulliNB()))  # 베르누이 나이브 베이즈 모델 확률 기반
models.append(('RF', RandomForestClassifier()))  # 랜덤포레스트 모델 의사결정 나무 여러개
models.append(('SVM', SVC(gamma='auto')))  # SVM 모델  
models.append(('XGB', XGBClassifier()))  # XGB 모델  트리기반 앙상블+ 부스팅(보정)

for name, model in models:
    model.fit(x_train, y_train)
    msg = "%s - train_score : %f, test score : %f" % (name, model.score(x_train, y_train), model.score(x_test, y_test))
    print(msg)
# Out:
# KNN - train_score : 0.885987, test score : 0.831972
# NB-M - train_score : 0.836020, test score : 0.814749
# NB-B - train_score : 0.907078, test score : 0.866416
# RF - train_score : 0.999945, test score : 0.841466
# SVM - train_score : 0.821996, test score : 0.806359
# XGB - train_score : 0.947659, test score : 0.872378

# %%
# xgb 모델에서 변수 중요도를 출력합니다.
max_num_features = 20
ax = xgb.plot_importance(models[-1][1], height = 1, grid = True, importance_type = 'gain', show_values = False, max_num_features = max_num_features)
ytick = ax.get_yticklabels()
word_importance = []
for i in range(max_num_features):
    word_importance.append(vectorizer.get_feature_names()[int(ytick[i].get_text().split('f')[1])])

ax.set_yticklabels(word_importance)

plt.rcParams['figure.figsize'] = (10, 15)
plt.xlabel('The F-Score for each features')
plt.ylabel('Importances')
plt.show()
# Out:
# C:\Users\gotsl\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
# xgb 모델에서 변수 중요도를 출력합니다.
max_num_features = 30
ax = xgb.plot_importance(models[-1][1], height = 1, grid = True, importance_type = 'gain', show_values = False, max_num_features = max_num_features)
ytick = ax.get_yticklabels()# y축의 값가져오기
word_importance = []# 토큰 매핑
for i in range(max_num_features):
    word_importance.append(vectorizer.get_feature_names()[int(ytick[i].get_text().split('f')[1])])
#f를 뺀 형태로 int형으로 위에 단여장과 같은 단어를 가져와서 
ax.set_yticklabels(word_importance)#세팅해준다.

plt.rcParams['figure.figsize'] = (10, 15)
plt.xlabel('The F-Score for each features')
plt.ylabel('Importances')
plt.show()

# %%
from sklearn.metrics import confusion_matrix

# 의사결정나무 모델에 confusion matrix를 사용하기 위하여 테스트 데이터의 예측값을 저장합니다.
model_predition = models[3][1].predict(x_test)

# sklearn에서 제공하는 confusion_matrix를 사용합니다.
cm = confusion_matrix(y_test, model_predition)

# 출력 파트 - seaborn의 heatmap을 사용
plt.rcParams['figure.figsize'] = (5, 5)
sns.set(style = 'dark', font_scale = 1.4)
ax = sns.heatmap(cm, annot=True)
plt.xlabel('Real Data')
plt.ylabel('Prediction')
plt.show()
cm

#혼동행렬
# Out:
# array([[3626,   26],
#        [ 692,  185]], dtype=int64)

# %%
"""
위 confusion matrix에서 x 축은 실제 데이터의 label을 의미하고 y 축은 예측한 데이터의 label을 의미합니다.

0,0 의 값: 추천함(Pass) 이라고 예측했을 때, 실제 데이터가 추천함(Pass)인 경우의 개수
0,1 의 값: 추천 하지 않음(Fail) 이라고 예측했을 때, 실제 데이터가 추천함(Pass)인 경우의 개수
1,0 의 값: 추천함(Pass) 이라고 예측했을 때, 실제 데이터가 추천 하지 않음(Fail)인 경우의 개수
1,1 의 값: 추천 하지 않음(Fail) 이라고 에측했을 때, 실제 데이터가 추천 하지 않음(Fail)인 경우의 개수
"""

# %%
from sklearn.metrics import confusion_matrix

# 의사결정나무 모델에 confusion matrix를 사용하기 위하여 테스트 데이터의 예측값을 저장합니다.
model_predition = models[-1][1].predict(x_test)

# sklearn에서 제공하는 confusion_matrix를 사용합니다.
cm = confusion_matrix(y_test, model_predition)

# 출력 파트 - seaborn의 heatmap을 사용
plt.rcParams['figure.figsize'] = (5, 5)
sns.set(style = 'dark', font_scale = 1.4)
ax = sns.heatmap(cm, annot=True)
plt.xlabel('Real Data')
plt.ylabel('Prediction')
plt.show()
cm
# Out:
# array([[3522,  130],
#        [ 448,  429]], dtype=int64)

# %%
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score

# sklearn에서 제공하는 recall_score, precision_score를 사용하여 recall과 precision 결과물을 출력합니다.
print("Recall score: {}".format(recall_score(y_test, model_predition)))
print("Precision score: {}".format(precision_score(y_test, model_predition)))
# Out:
# Recall score: 0.48916761687571264
# Precision score: 0.7674418604651163

# %%
# 0번부터 4번까지 5개를 출력해보겠습니다.
for i in range(5): 
    
    # 의사결정나무 모델을 사용하였습니다.
    prediction = model.predict(x_test[i])
    print("{} 번째 테스트 데이터 문장: \n{}".format(i, df_clean['Review Text'][i]))
    print("{} 번째 테스트 데이터의 예측 결과: {}, 실제 데이터: {}\n".format(i, prediction[0], y_test[i]))
# Out:
# 0 번째 테스트 데이터 문장:
# Absolutely wonderful - silky and sexy and comfortable
# 0 번째 테스트 데이터의 예측 결과: 0, 실제 데이터: 0
#
# 1 번째 테스트 데이터 문장:
# Love this dress!  it's sooo pretty.  i happened to find it in a store, and i'm glad i did bc i never would have ordered it online bc it's petite.  i bought a petite and am 5'8".  i love the length on me- hits just a little below the knee.  would definitely be a true midi on someone who is truly petite.
# 1 번째 테스트 데이터의 예측 결과: 0, 실제 데이터: 0
#
# 2 번째 테스트 데이터 문장:
# I had such high hopes for this dress and really wanted it to work for me. i initially ordered the petite small (my usual size) but i found this to be outrageously small. so small in fact that i could not zip it up! i reordered it in petite medium, which was just ok. overall, the top half was comfortable and fit nicely, but the bottom half had a very tight under layer and several somewhat cheap (net) over layers. imo, a major design flaw was the net over layer sewn directly into the zipper - it c
# 2 번째 테스트 데이터의 예측 결과: 0, 실제 데이터: 1
#
# 3 번째 테스트 데이터 문장:
# I love, love, love this jumpsuit. it's fun, flirty, and fabulous! every time i wear it, i get nothing but great compliments!
# 3 번째 테스트 데이터의 예측 결과: 0, 실제 데이터: 0
#
# 4 번째 테스트 데이터 문장:
# This shirt is very flattering to all due to the adjustable front tie. it is the perfect length to wear with leggings and it is sleeveless so it pairs well with any cardigan. love this shirt!!!
# 4 번째 테스트 데이터의 예측 결과: 0, 실제 데이터: 0
